# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet

# %%
data = pd.read_csv('./data/processed_data_2.csv', encoding='euc-kr')
data
# Out:
#       Unnamed: 0       nickname  score  \
# 0              0   karolinernes     50
# 1              1  mikyung782021     50
# 2              2       shinobu2     20
# 3              3   sharpgoodman     50
# 4              4        sunkeem     50
# ...          ...            ...    ...
# 3559        3559          Jay L     50
# 3560        3560            본 리     40
# 3561        3561       KilsuKim     40
# 3562        3562       yooo1357     50
# 3563        3563      kingishes     50
#
#                                                  review   stay_date  \
# 0     이그제큐티브 라운지 칵테일 뷔페는 생각보다 넘 별로였어요 메뉴가 얼마 없어서 ifc...  2021-07-01
# 1     직원분들 모두들 너무 친전하셨고 말하지 않아도 무엇이 필요한지 먼저 오퍼해 주셨어요...  2021-07-01
# 2     가격대비 메리크가 없으며 이제는 가격을 어느정도 지불해야지만 앞의 조망을 즐길수 있...  2021-07-01
# 3     가족들과 즐거운 여름 휴가를 보낼 수 있었습니다 더운 여름이었지만 11시쯤 걸어다닌...  2021-07-01
# 4     위치 주차 시설 서비스 등 호텔이 제공해야 할 모든면이 편리하고 좋았다 자녀들과 함...  2021-07-01
# ...                                                 ...         ...
# 3559  매전 출장올때마다 이곳만 이용하는데 깔끔하고 친절한 서비스에 항상 만족하고있어요 욕...  2018-07-01
# 3560  깨끗하고 펍도 있어서 좋아요  방도 넒고 시설도 괜찮네요 프론트 직원들도 너무 친절...  2018-07-01
# 3561  호텔에 도착하면 먼저 입구에 비치된 시원한 물한잔을 마십니다 프론트 데스크 직원에게...  2018-07-01
# 3562  객실도 깔끔하고 공항과 가까워서 이동하기 편리했습니다 직원들도 친절히 설명해주어서 ...  2018-06-01
# 3563  제주 공항과 가깝고 깔끔하고 가성비 좋은 호텔입니다 여기에 더불어 조식도 끝내주고요...  2018-06-01
#
#       sentimental_score_negative  sentimental_score_positive  topic_score_#0  \
# 0                      -1.531325                    1.986892        0.040136
# 1                      -2.686230                    3.260286        0.071453
# 2                       1.622923                   -1.981798        0.045082
# 3                      -3.021251                    3.449478        0.088896
# 4                      -2.996761                    3.426380        0.071519
# ...                          ...                         ...             ...
# 3559                   -3.008451                    3.428343        0.088896
# 3560                   -3.019018                    3.506316        0.438379
# 3561                   -1.334387                    1.940832        0.015828
# 3562                   -3.029234                    3.538146        0.331866
# 3563                   -3.046722                    3.497742        0.574836
#
#       topic_score_#1  topic_score_#2  ...  topic_score_#0_positive  \
# 0           0.018102        0.019667  ...                 0.079746
# 1           0.008632        0.218631  ...                 0.232956
# 2           0.020333        0.022091  ...                -0.089343
# 3           0.526034        0.043561  ...                 0.306644
# 4           0.032256        0.035046  ...                 0.245051
# ...              ...             ...  ...                      ...
# 3559        0.040094        0.529501  ...                 0.304765
# 3560        0.052962        0.057541  ...                 1.537096
# 3561        0.050399        0.094277  ...                 0.030719
# 3562        0.040094        0.043561  ...                 1.174191
# 3563        0.040094        0.043561  ...                 2.010629
#
#       topic_score_#1_positive  topic_score_#2_positive  \
# 0                    0.035967                 0.039077
# 1                    0.028144                 0.712798
# 2                   -0.040295                -0.043780
# 3                    1.814544                 0.150261
# 4                    0.110522                 0.120079
# ...                       ...                      ...
# 3559                 0.137455                 1.815312
# 3560                 0.185701                 0.201758
# 3561                 0.097816                 0.182976
# 3562                 0.141857                 0.154124
# 3563                 0.140237                 0.152364
#
#       topic_score_#3_positive  topic_score_#4_positive  \
# 0                    0.038117                 0.054713
# 1                    1.053158                 0.042813
# 2                   -0.042704                -0.305489
# 3                    0.146570                 0.210385
# 4                    1.456677                 0.168127
# ...                       ...                      ...
# 3559                 0.145672                 0.209096
# 3560                 0.196802                 0.282488
# 3561                 0.014683                 0.524845
# 3562                 0.150338                 1.075458
# 3563                 0.148621                 0.213329
#
#       topic_score_#5_positive  topic_score_#6_positive  \
# 0                    0.029818                 0.069929
# 1                    0.023333                 0.225274
# 2                   -0.033407                -0.078344
# 3                    0.114659                 0.268893
# 4                    0.091628                 0.214882
# ...                       ...                      ...
# 3559                 0.113956                 0.267245
# 3560                 0.153955                 0.361047
# 3561                 0.011486                 0.110899
# 3562                 0.117606                 0.275805
# 3563                 0.116263                 0.272655
#
#       topic_score_#7_positive  topic_score_#8_positive  \
# 0                    1.555181                 0.038497
# 1                    0.023037                 0.030124
# 2                   -0.032983                -1.264091
# 3                    0.113204                 0.148031
# 4                    0.090466                 0.788070
# ...                       ...                      ...
# 3559                 0.112511                 0.147124
# 3560                 0.152001                 0.198764
# 3561                 0.011341                 0.014829
# 3562                 0.116114                 0.151836
# 3563                 0.114788                 0.150102
#
#       topic_score_#9_positive
# 0                    0.045845
# 1                    0.888650
# 2                   -0.051362
# 3                    0.176287
# 4                    0.140877
# ...                       ...
# 3559                 0.175207
# 3560                 0.236703
# 3561                 0.941237
# 3562                 0.180818
# 3563                 0.178753
#
# [3564 rows x 37 columns]

# %%
data = data.loc[:,'stay_date':]

# %%
for i in range(10):
    column = 'topic_score_#' + str(i) + '_positive'
    globals()['df_{}'.format(i)] = data[['stay_date', column]].copy().rename(columns={'stay_date':'ds', column:'y'})

# %%
model0 = Prophet(changepoint_prior_scale=10, 
                changepoints=['2020-02-01'], 
                yearly_seasonality=10, 
                weekly_seasonality=False, 
                daily_seasonality=False, 
                growth='linear')
model0.add_country_holidays(country_name='KR')

# %%
model0.fit(df_0)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
future = model0.make_future_dataframe(periods=0, freq='M')
forecast = model0.predict(future)
fig1 = model0.plot(forecast)

# %%
fig2 = model0.plot_components(forecast)

# %%
model1 = Prophet(changepoint_prior_scale=10, 
                changepoints=['2020-02-01'], 
                yearly_seasonality=10, 
                weekly_seasonality=False, 
                daily_seasonality=False, 
                growth='linear')
model1.add_country_holidays(country_name='KR')

# %%
model1.fit(df_1)
future = model1.make_future_dataframe(periods=0, freq='M')
forecast = model1.predict(future)

# %%
fig1 = model1.plot(forecast)

# %%
fig2 = model1.plot_components(forecast)

# %%
model2 = Prophet(changepoint_prior_scale=10, 
                changepoints=['2020-02-01'], 
                yearly_seasonality=10, 
                weekly_seasonality=False, 
                daily_seasonality=False, 
                growth='linear')
model2.add_country_holidays(country_name='KR')

# %%
model2.fit(df_2)
future = model2.make_future_dataframe(periods=0, freq='M')
forecast = model2.predict(future)

# %%
fig1 = model2.plot(forecast)

# %%
fig2 = model2.plot_components(forecast)

# %%
model3 = Prophet(changepoint_prior_scale=10, 
                changepoints=['2020-02-01'], 
                yearly_seasonality=10, 
                weekly_seasonality=False, 
                daily_seasonality=False, 
                growth='linear')
model3.add_country_holidays(country_name='KR')

# %%
model3.fit(df_3)
future = model3.make_future_dataframe(periods=0, freq='M')
forecast = model3.predict(future)

# %%
fig1 = model3.plot(forecast)

# %%
fig2 = model3.plot_components(forecast)

# %%
model4 = Prophet(changepoint_prior_scale=10, 
                changepoints=['2020-02-01'], 
                yearly_seasonality=10, 
                weekly_seasonality=False, 
                daily_seasonality=False, 
                growth='linear')
model4.add_country_holidays(country_name='KR')

model4.fit(df_4)
future = model4.make_future_dataframe(periods=0, freq='M')
forecast = model4.predict(future)

# %%
fig1 = model4.plot(forecast)

# %%
fig2 = model4.plot_components(forecast)

# %%
model5 = Prophet(changepoint_prior_scale=10, 
                changepoints=['2020-02-01'], 
                yearly_seasonality=10, 
                weekly_seasonality=False, 
                daily_seasonality=False, 
                growth='linear')
model5.add_country_holidays(country_name='KR')

model5.fit(df_5)
future = model5.make_future_dataframe(periods=0, freq='M')
forecast = model5.predict(future)

# %%
fig1 = model5.plot(forecast)

# %%
fig2 = model5.plot_components(forecast)

# %%
model6 = Prophet(changepoint_prior_scale=10, 
                changepoints=['2020-02-01'], 
                yearly_seasonality=10, 
                weekly_seasonality=False, 
                daily_seasonality=False, 
                growth='linear')
model6.add_country_holidays(country_name='KR')

model6.fit(df_6)
future = model6.make_future_dataframe(periods=0, freq='M')
forecast = model6.predict(future)

# %%
fig1 = model6.plot(forecast)

# %%
fig2 = model6.plot_components(forecast)

# %%
model7 = Prophet(changepoint_prior_scale=10, 
                changepoints=['2020-02-01'], 
                yearly_seasonality=10, 
                weekly_seasonality=False, 
                daily_seasonality=False, 
                growth='linear')
model7.add_country_holidays(country_name='KR')

model7.fit(df_7)
future = model7.make_future_dataframe(periods=0, freq='M')
forecast = model7.predict(future)

# %%
fig1 = model7.plot(forecast)

# %%
fig2 = model7.plot_components(forecast)

# %%
model8 = Prophet(changepoint_prior_scale=10, 
                changepoints=['2020-02-01'], 
                yearly_seasonality=10, 
                weekly_seasonality=False, 
                daily_seasonality=False, 
                growth='linear')
model8.add_country_holidays(country_name='KR')

model8.fit(df_8)
future = model8.make_future_dataframe(periods=0, freq='M')
forecast = model8.predict(future)

# %%
fig1 = model8.plot(forecast)

# %%
fig2 = model8.plot_components(forecast)

# %%
model9 = Prophet(changepoint_prior_scale=10, 
                changepoints=['2020-02-01'], 
                yearly_seasonality=10, 
                weekly_seasonality=False, 
                daily_seasonality=False, 
                growth='linear')
model9.add_country_holidays(country_name='KR')

model9.fit(df_9)
future = model9.make_future_dataframe(periods=0, freq='M')
forecast = model9.predict(future)

# %%
fig1 = model9.plot(forecast)

# %%
fig2 = model9.plot_components(forecast)
